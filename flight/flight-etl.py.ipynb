# %% [markdown]
# flight-etl
# Purpose:      Batch load of flight legs from landing volume to silver table.
# Owner:        Arun (learning project, mock of WestJet Data Services standards)
# Source(s):    wj_airline_ops_<env>.landing volume, OpenSky flight files
# Target(s):    wj_airline_ops_<env>.silver.flight_legs
# Schedule:     daily 06:00 MT (to be created by Data Services, not the developer)
# Offset:       none, full daily file, idempotent overwrite by flight_date
# Idempotency:  re-run over same date replaces that date only, no duplicates
# Dependencies: Configs/config.py, flight-helpers, flight-db-helpers
# Last reviewed: 2026-09-19
